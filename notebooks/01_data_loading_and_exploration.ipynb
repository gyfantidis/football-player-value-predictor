# %% [markdown]
# # 01 — Data Loading
#
# **Goal:** Load all 10 raw CSV files, confirm they are readable, print shape / dtypes / null counts per dataset.
#
# **Outputs:** Nothing saved to disk — purely diagnostic.
#
# **Next:** `02_eda_raw.ipynb`

# %%
import pandas as pd
import os

# %%
# Paths — relative to the notebooks/ folder
RAW_DATA_PATH = "../data/raw/"

assert os.path.exists(RAW_DATA_PATH), f"Folder not found: {RAW_DATA_PATH}"
print("Files in raw data folder:")
for f in sorted(os.listdir(RAW_DATA_PATH)):
    print(f"  {f}")
# Out:
# Files in raw data folder:
#   appearances.csv
#   club_games.csv
#   clubs.csv
#   competitions.csv
#   game_events.csv
#   game_lineups.csv
#   games.csv
#   player_valuations.csv
#   players.csv
#   transfers.csv

# %%
FILES = [
    "players.csv",
    "appearances.csv",
    "player_valuations.csv",
    "club_games.csv",
    "game_lineups.csv",
    "game_events.csv",
    "games.csv",
    "clubs.csv",
    "competitions.csv",
    "transfers.csv",
]

data = {}
for filename in FILES:
    name = filename.replace(".csv", "")
    path = os.path.join(RAW_DATA_PATH, filename)
    try:
        data[name] = pd.read_csv(path, low_memory=False)
        r, c = data[name].shape
        print(f"OK       {filename:<35} {r:>10,} rows  {c:>3} cols")
    except FileNotFoundError:
        print(f"MISSING  {filename}")
# Out:
# OK       players.csv                             34,291 rows   23 cols
# OK       appearances.csv                      1,722,865 rows   13 cols
# OK       player_valuations.csv                  448,965 rows    6 cols
# OK       club_games.csv                         155,990 rows   11 cols
# OK       game_lineups.csv                     2,680,694 rows   10 cols
# OK       game_events.csv                      1,100,360 rows   11 cols
# OK       games.csv                               77,995 rows   23 cols
# OK       clubs.csv                                  451 rows   17 cols
# OK       competitions.csv                            44 rows   11 cols
# OK       transfers.csv                           85,293 rows   10 cols

# %%
# Per-dataset column summary: dtype, null count, null %, unique values
for name, df in data.items():
    sep = '=' * 60
    print(f"\n{sep}")
    print(f"  {name.upper()}  —  {df.shape[0]:,} rows x {df.shape[1]} cols")
    print(sep)
    info = pd.DataFrame({
        "dtype":      df.dtypes,
        "null_count": df.isnull().sum(),
        "null_pct":   (df.isnull().sum() / len(df) * 100).round(2),
        "unique":     df.nunique(),
    })
    print(info.to_string())
# Out:
# ============================================================
#   PLAYERS  —  34,291 rows x 23 cols
# ============================================================
#                                         dtype  null_count  null_pct  unique
# player_id                               int64           0      0.00   34291
# first_name                                str        2138      6.23    7351
# last_name                                 str           0      0.00   24855
# name                                      str           0      0.00   33541
# last_season                             int64           0      0.00      14
# current_club_id                         int64           0      0.00     449
# player_code                               str           0      0.00   33496
# country_of_birth                          str        2916      8.50     186
# city_of_birth                             str        2589      7.55    8828
# country_of_citizenship                    str         355      1.04     186
# date_of_birth                             str          49      0.14    9670
# sub_position                              str         189      0.55      13
# position                                  str           0      0.00       5
# foot                                      str        2663      7.77       3
# height_in_cm                          float64        2394      6.98      53
# contract_expiration_date                  str       12497     36.44     142
# agent_name                                str       16518     48.17    3071
# image_url                                 str           0      0.00   28577
# url                                       str           0      0.00   34291
# current_club_domestic_competition_id      str           0      0.00      14
# current_club_name                         str           0      0.00     449
# market_value_in_eur                   float64        2916      8.50     120
# highest_market_value_in_eur           float64        2916      8.50     210
#
# ============================================================
#   APPEARANCES  —  1,722,865 rows x 13 cols
# ============================================================
#                         dtype  null_count  null_pct   unique
# appearance_id             str           0       0.0  1722865
# game_id                 int64           0       0.0    70120
# player_id               int64           0       0.0    26489
# player_club_id          int64           0       0.0     1090
# player_current_club_id  int64           0       0.0      450
# date                      str           0       0.0     3999
# player_name               str           4       0.0    25928
# competition_id            str           0       0.0       43
# yellow_cards            int64           0       0.0        3
# red_cards               int64           0       0.0        2
# goals                   int64           0       0.0        7
# assists                 int64           0       0.0        7
# minutes_played          int64           0       0.0      122
#
# ============================================================
#   PLAYER_VALUATIONS  —  448,965 rows x 6 cols
# ============================================================
#                                      dtype  null_count  null_pct  unique
# player_id                            int64           0      0.00   31375
# date                                   str           0      0.00    5559
# market_value_in_eur                  int64           0      0.00     423
# current_club_name                      str           0      0.00    6550
# current_club_id                      int64           0      0.00    3301
# player_club_domestic_competition_id    str       31081      6.92      14
#
# ============================================================
#   CLUB_GAMES  —  155,990 rows x 11 cols
# ============================================================
#                          dtype  null_count  null_pct  unique
# game_id                  int64           0      0.00   77995
# club_id                  int64           0      0.00    2927
# own_goals                int64           0      0.00      18
# own_position           float64       48190     30.89      21
# own_manager_name           str        1664      1.07    6357
# opponent_id              int64           0      0.00    2927
# opponent_goals           int64           0      0.00      18
# opponent_position      float64       48190     30.89      21
# opponent_manager_name      str        1664      1.07    6357
# hosting                    str           0      0.00       2
# is_win                   int64           0      0.00       2
#
# ============================================================
#   GAME_LINEUPS  —  2,680,694 rows x 10 cols
# ============================================================
#                  dtype  null_count  null_pct   unique
# game_lineups_id    str           0       0.0  2680694
# date               str           0       0.0     3770
# game_id          int64           0       0.0    69304
# player_id        int64           0       0.0   103524
# club_id          int64           0       0.0     2789
# player_name        str           0       0.0   100055
# type               str           0       0.0        2
# position           str           3       0.0       18
# number             str           0       0.0      104
# team_captain     int64           0       0.0        2
#
# ============================================================
#   GAME_EVENTS  —  1,100,360 rows x 11 cols
# ============================================================
#                     dtype  null_count  null_pct   unique
# game_event_id         str           0      0.00  1100360
# date                  str           0      0.00     4079
# game_id             int64           0      0.00    77854
# minute              int64           0      0.00      121
# type                  str           0      0.00        4
# club_id             int64           0      0.00     2824
# club_name             str           0      0.00     3062
# player_id           int64           0      0.00    66959
# description           str       88929      8.08     8619
# player_in_id      float64      566766     51.51    59905
# player_assist_id  float64      934898     84.96    26136
#
# ============================================================
#   GAMES  —  77,995 rows x 23 cols
# ============================================================
#                           dtype  null_count  null_pct  unique
# game_id                   int64           0      0.00   77995
# competition_id              str           0      0.00      44
# season                    int64           0      0.00      14
# round                       str           0      0.00     118
# date                        str           0      0.00    4081
# home_club_id              int64           0      0.00    2636
# away_club_id              int64           0      0.00    2287
# home_club_goals           int64           0      0.00      16
# away_club_goals           int64           0      0.00      18
# home_club_position      float64       24095     30.89      21
# away_club_position      float64       24095     30.89      21
# home_club_manager_name      str         832      1.07    5503
# away_club_manager_name      str         832      1.07    5134
# stadium                     str         253      0.32    2594
# attendance              float64       10061     12.90   30845
# referee                     str         662      0.85    2681
# url                         str           0      0.00   77995
# home_club_formation         str        9145     11.73      54
# away_club_formation         str        9002     11.54      66
# home_club_name              str          86      0.11    2557
# away_club_name              str          35      0.04    2254
# aggregate                   str           0      0.00     118
# competition_type            str           0      0.00       4
#
# ============================================================
#   CLUBS  —  451 rows x 17 cols
# ============================================================
#                            dtype  null_count  null_pct  unique
# club_id                    int64           0      0.00     451
# club_code                    str           0      0.00     451
# name                         str           0      0.00     451
# domestic_competition_id      str           0      0.00      14
# total_market_value       float64         451    100.00       0
# squad_size                 int64           0      0.00      29
# average_age              float64          38      8.43      76
# foreigners_number          int64           0      0.00      29
# foreigners_percentage    float64          52     11.53     186
# national_team_players      int64           0      0.00      22
# stadium_name                 str           0      0.00     431
# stadium_seats              int64           0      0.00     411
# net_transfer_record          str           0      0.00     312
# coach_name               float64         451    100.00       0
# last_season                int64           0      0.00      14
# filename                     str           0      0.00      14
# url                          str           0      0.00     451
#
# ============================================================
#   COMPETITIONS  —  44 rows x 11 cols
# ============================================================
#                           dtype  null_count  null_pct  unique
# competition_id              str           0      0.00      44
# competition_code            str           0      0.00      43
# name                        str           0      0.00      43
# sub_type                    str           0      0.00      12
# type                        str           0      0.00       4
# country_id                int64           0      0.00      15
# country_name                str           8     18.18      14
# domestic_league_code        str           8     18.18      14
# confederation               str           0      0.00       1
# url                         str           0      0.00      44
# is_major_national_league   bool           0      0.00       2
#
# ============================================================
#   TRANSFERS  —  85,293 rows x 10 cols
# ============================================================
#                        dtype  null_count  null_pct  unique
# player_id              int64           0      0.00   11033
# transfer_date            str           0      0.00    4357
# transfer_season          str           0      0.00      34
# from_club_id           int64           0      0.00   10200
# to_club_id             int64           0      0.00    7733
# from_club_name           str           0      0.00   10764
# to_club_name             str           0      0.00    8269
# transfer_fee         float64       29354     34.42    1062
# market_value_in_eur  float64       32640     38.27     176
# player_name              str           0      0.00   10938

# %%
# Sanity checks on the 3 core files
players = data["players"]
apps    = data["appearances"]
vals    = data["player_valuations"]

print("PLAYERS")
print(f"  Total: {len(players):,}")
print(players["position"].value_counts().to_string())

print("\nAPPEARANCES")
print(f"  Total rows:     {len(apps):,}")
print(f"  Unique players: {apps['player_id'].nunique():,}")
print(f"  Unique games:   {apps['game_id'].nunique():,}")

print("\nVALUATIONS")
print(f"  Total rows:     {len(vals):,}")
print(f"  Unique players: {vals['player_id'].nunique():,}")
mv = vals["market_value_in_eur"]
print(f"  Value range:    EUR {mv.min():,.0f} — EUR {mv.max():,.0f}")
# Out:
# PLAYERS
#   Total: 34,291
# position
# Defender      10893
# Midfield       9903
# Attack         9400
# Goalkeeper     3906
# Missing         189
#
# APPEARANCES
#   Total rows:     1,722,865
#   Unique players: 26,489
#   Unique games:   70,120
#
# VALUATIONS
#   Total rows:     448,965
#   Unique players: 31,375
#   Value range:    EUR 0 — EUR 200,000,000
